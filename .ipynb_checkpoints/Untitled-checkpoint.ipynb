# %%
import pandas as pd
from matplotlib import pyplot as plt
from pandas.tseries.offsets import DateOffset
directory = "C://Users/Youngju Hong/Documents/GitHub/2020_Fall"

# %%
ratings = pd.read_excel(f"{directory}/2020 빅콘테스트 데이터분석분야-챔피언리그_시청률 데이터.xlsx", header = 1)
sales = pd.read_excel(f"{directory}/2020 빅콘테스트 데이터분석분야-챔피언리그_2019년 실적데이터.xlsx", header = 1)

# %%
ratings
# Out:
#                      시간대  2019-01-01  2019-01-02  2019-01-03  2019-01-04  \
# 0                  02:00       0.000       0.000       0.000       0.000
# 1                  02:01       0.000       0.000       0.000       0.000
# 2                  02:02       0.000       0.000       0.000       0.000
# 3                  02:03       0.000       0.000       0.014       0.000
# 4                  02:04       0.000       0.000       0.000       0.000
# ...                  ...         ...         ...         ...         ...
# 1436               01:56       0.000       0.000       0.000       0.000
# 1437               01:57       0.000       0.000       0.000       0.000
# 1438               01:58       0.000       0.000       0.000       0.000
# 1439               01:59       0.000       0.000       0.000       0.000
# 1440  월화수목금토일02:00-01:59       0.004       0.006       0.002       0.003
#
#       2019-01-05  2019-01-06  2019-01-07  2019-01-08  2019-01-09  ...  \
# ...

# %%
sales
# Out:
#                      방송일시      노출(분)    마더코드    상품코드  \
# 0     2019-01-01 06:00:00  20.000000  100346  201072
# 1     2019-01-01 06:00:00        NaN  100346  201079
# 2     2019-01-01 06:20:00  20.000000  100346  201072
# 3     2019-01-01 06:20:00        NaN  100346  201079
# 4     2019-01-01 06:40:00  20.000000  100346  201072
# ...                   ...        ...     ...     ...
# 38304 2020-01-01 00:20:00  20.000000  100073  200196
# 38305 2020-01-01 00:40:00  20.000000  100073  200196
# 38306 2020-01-01 01:00:00  20.000000  100073  200196
# 38307 2020-01-01 01:20:00  20.000000  100490  201478
# 38308 2020-01-01 01:40:00  17.166667  100490  201478
#
#                             상품명 상품군   판매단가        취급액  노출          일자     시간
# 0                 테이트 남성 셀린니트3종  의류  39900  2099000.0  20  2019-01-01  06:00
# 1                 테이트 여성 셀린니트3종  의류  39900  4371000.0   0  2019-01-01  06:00
# 2                 테이트 남성 셀린니트3종  의류  39900  3262000.0  20  2019-01-01  06:20
# ...

# %%
sales["노출"] = sales["노출(분)"].fillna(0).astype(int)
sales["일자"] = sales["방송일시"].apply(lambda x: str(x).split(" "))

# %%
sales["시간"] = sales["일자"].apply(lambda x: x[1][:str(x[1]).rfind(":")])
sales["일자"] = sales["일자"].apply(lambda x: x[0])

# %%
ratings = ratings.iloc[:1440, :]
ratings["시간대"] = pd.to_datetime(ratings["시간대"])
# Out:
# C:\Users\Youngju Hong\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
pd.to_datetime(ratings.loc[100, "시간대"],  format = "%H:%M") +pd.DateOffset(minutes = 20)
# Out:
# Timestamp('2020-08-25 04:00:00')

# %%
ts = pd.Timestamp('2017-01-01 09:10:11')
ts + DateOffset(months=2)
# Out:
# Timestamp('2017-03-01 09:10:11')

# %%
sales.loc[100, "시간"]
# Out:
# '12:20'

# %%
for i in sales.index:
    tempTime = pd.to_datetime(sales.loc[100,"시간"])
    
    
    ratings.loc[ratings["시간대"] == sales.loc[100,"시간"], sales.loc[100, "일자"]]
# Out:
#   File "<ipython-input-155-91c98e8a56ad>", line 5
#     ratings.loc[ratings["시간대"] == sales.loc[100,"시간"], sales.loc[100, "일자"]]
#           ^
# SyntaxError: invalid syntax

# %%
tempTime = pd.to_datetime(sales.loc[100,"시간"]) #1. retrieve time data from "sales"

tempTime
# Out:
# Timestamp('2020-08-25 12:20:00')

# %%
tempTime = pd.to_datetime(sales.loc[100,"시간"])
tempTime + pd.DateOffset(minutes = 20)
# Out:
# Timestamp('2020-08-25 12:40:00')

# %%
tempTime_added
# Out:
# '06:20'

# %%
x = "06:40"

# %%
x
# Out:
# '06:40'

# %%
int(x[3:]) + 20
# Out:
# 60
