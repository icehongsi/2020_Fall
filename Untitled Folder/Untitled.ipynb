# %%
EMPLOYEE_csv = 'Fname,Minit,Lname,Ssn,Bdate,Address,Sex,Salary,Superssn,Dno\r\nJohn,B,Smith,123456789,1965-01-09,731-Fondren-Houston-TX,M,30000.00,333445555,5\r\nFranklin,T,Wong,333445555,1955-12-08,638-Voss-Houston-TX,M,40000.00,888665555,5\r\nJoyce,A,English,453453453,1972-07-31,5631-Rice-Houston-TX,F,25000.00,333445555,5\r\nRamesh,K,Narayan,666884444,1962-09-15,975-Fire-Oak-Humble-TX,M,38000.00,333445555,5\r\nJames,E,Borg,888665555,1937-11-10,450-Stone-Houston-TX,M,55000.00,,1\r\nJennifer,S,Wallace,987654321,1941-06-20,291-Berry-Bellaire-TX,F,43000.00,888665555,4\r\nAhmad,V,Jabbar,987987987,1969-03-29,980-Dallas-Houston-TX,M,25000.00,987654321,4\r\nAlicia,J,Zelaya,999887777,1968-01-19,3321-Castle-Spring-TX,F,25000.00,987654321,4\r\n'
DEPARTMENT_csv = 'Dname,Dnumber,Mgrssn,Mgrstartdate\r\nHeadquarters,1,888665555,1981-06-19\r\nAdministration,4,987654321,1995-01-01\r\nResearch,5,333445555,1988-05-22\r\n'
DEPT_LOCATIONS_csv = 'Dnumber,Dlocation\r\n1,Houston\r\n4,Stafford\r\n5,Bellaire\r\n5,Houston\r\n5,Sugarland\r\n'
PROJECT_csv = 'Pname,Pnumber,Plocation,Dnum\r\nProductX,1,Bellaire,5\r\nProductY,2,Sugarland,5\r\nProductZ,3,Houston,5\r\nComputerization,10,Stafford,4\r\nReorganization,20,Houston,1\r\nNewbenefits,30,Stafford,4\r\n'
WORKS_ON_csv = 'Essn,Pno,Hours\r\n123456789,1,32.5\r\n123456789,2,7.5\r\n333445555,2,10.0\r\n333445555,3,10.0\r\n333445555,10,10.0\r\n333445555,20,10.0\r\n453453453,1,20.0\r\n453453453,2,20.0\r\n666884444,3,40.0\r\n888665555,20,\r\n987654321,20,15.0\r\n987654321,30,20.0\r\n987987987,10,35.0\r\n987987987,30,5.0\r\n999887777,10,10.0\r\n999887777,30,30.0\r\n'
DEPENDENT_csv = 'Essn,Dependent_name,Sex,Bdate,Relationship\r\n123456789,Alice,F,1988-12-30,Daughter\r\n123456789,Elizabeth,F,1967-05-05,Spouse\r\n123456789,Michael,M,1988-01-04,Son\r\n333445555,Alice,F,1986-04-05,Daughter\r\n333445555,Joy,F,1958-05-03,Spouse\r\n333445555,Theodore,M,1983-10-25,Son\r\n987654321,Abner,M,1942-02-28,Spouse\r\n'

# import packages

import pandas as pd
from io import StringIO 
import re

# Tables
EMPLOYEE = pd.read_csv(StringIO(EMPLOYEE_csv))
DEPARTMENT = pd.read_csv(StringIO(DEPARTMENT_csv))
DEPT_LOCATIONS = pd.read_csv(StringIO(DEPT_LOCATIONS_csv))
PROJECT = pd.read_csv(StringIO(PROJECT_csv))
WORKS_ON = pd.read_csv(StringIO(WORKS_ON_csv))
DEPENDENT = pd.read_csv(StringIO(DEPENDENT_csv))

# short_names for Tables
E = EMPLOYEE
D = DEPARTMENT
DL = DEPT_LOCATIONS
P = PROJECT
WO = WORKS_ON
DE = DEPENDENT

def rename(R, C):
    return R.rename(columns=C)

def select(R, C):
    # The following substitution may NOT work 
    # when column name is equal to a string value in C
    tokens = re.split(r'(\W+)', C)
    new_tokens = ["R." + token  if token in R.columns else token \
                  for token in tokens] 
    selected = eval(''.join(new_tokens))
    return R[selected].reset_index(drop=True)

def project(R, C):
    return R[C].drop_duplicates().reset_index(drop=True)

def union(R, S):
    S.columns = R.columns
    T = pd.concat([R, S], ignore_index=True)
    T = T.drop_duplicates().reset_index(drop=True)
    return T

def intersect(R, S):
    S.columns = R.columns
    return R.merge(S).reset_index(drop=True)

def minus(R, S):
    S.columns = R.columns
    return pd.concat([R, S, S]).drop_duplicates(keep=False).reset_index(drop=True)

def product(R, S):
    """Determine Cartesian product of two data frames."""
    key = 'key'
    while key in R.columns or key in S.columns:
        key = '_' + key
    key_d = {key: 0}
    return pd.merge(R.assign(**key_d), S.assign(**key_d), on=key)\
           .drop(key, axis=1).reset_index(drop=True)

def natural_join(R, S):
    return pd.merge(R, S).reset_index(drop=True)

def natural_join2(R, S, keys_R, keys_S):
    return pd.merge(R, S, left_on=keys_R, right_on=keys_S)\
           .drop(keys_S, axis=1).reset_index(drop=True)

def division(R, S):
    Z = set(R.columns)
    X = set(S.columns)
    assert X <= Z
    Y = pd.Index(Z - X)
    T1 = project(R, Y)
    T2 = project(minus(product(T1, S), R), Y)
    T = minus(T1, T2)
    return T.reset_index(drop=True)

# %%
R = project(select(D, "Dname == 'Research'"), ["Dnumber"])
project(select(product(R,E), "Dnumber == Dno"), ["Fname", "Lname", "Address"])
# Out:
#       Fname    Lname                 Address
# 0      John    Smith  731-Fondren-Houston-TX
# 1  Franklin     Wong     638-Voss-Houston-TX
# 2     Joyce  English    5631-Rice-Houston-TX
# 3    Ramesh  Narayan  975-Fire-Oak-Humble-TX

# %%
D2 = rename(D, {'Dnumber': 'Dno'})
project(select(natural_join(E, D2), "Dname == 'Research'"), ["Fname", "Lname", "Address"])
# Out:
#       Fname    Lname                 Address
# 0      John    Smith  731-Fondren-Houston-TX
# 1  Franklin     Wong     638-Voss-Houston-TX
# 2     Joyce  English    5631-Rice-Houston-TX
# 3    Ramesh  Narayan  975-Fire-Oak-Humble-TX

# %%
'''
Query 3: For every project located in "Stafford", list the project name,
the controlling department name, and the department manager's last name, first name.
(Use natural_join2, No cartesian products and natural joins are allowed)
'''

manager = natural_join2(D, E, ["Mgrssn"], ["Ssn"])

project(
    select(natural_join2(P, manager, ["Dnum"], ["Dnumber"]), "Plocation == 'Stafford'"),
    ["Pname", "Dname", "Lname", "Fname"]
)
# Out:
#              Pname           Dname    Lname     Fname
# 0  Computerization  Administration  Wallace  Jennifer
# 1      Newbenefits  Administration  Wallace  Jennifer

# %%
'''
Query 4: Find the last name, first name of employees 
    who work on all the projects controlled by department number 4.'''

Employee_on_project_by_4 = select(
    natural_join2(WO, P, ["Pno"], ["Pnumber"]),
    "Dnum == 4"
)

project(natural_join2(Employee_on_project_by_4, E, ["Essn"], ["Ssn"]), ["Lname", "Fname"])
# Out:
#      Lname     Fname
# 0     Wong  Franklin
# 1   Jabbar     Ahmad
# 2   Zelaya    Alicia
# 3  Wallace  Jennifer

# %%
'''
Query 5: Make a list of project names for projects that involve an employee whose last name is "Wallace",
either as a worker or as a manager of the department that controls the project.
'''

select(
    natural_join2(WO, E, ["Essn"], ["Ssn"]),
    "Lname == 'Wallace'"
)
# Out:
#         Essn  Pno  Hours     Fname Minit    Lname       Bdate  \
# 0  987654321   20   15.0  Jennifer     S  Wallace  1941-06-20
# 1  987654321   30   20.0  Jennifer     S  Wallace  1941-06-20
#
#                  Address Sex   Salary     Superssn  Dno
# 0  291-Berry-Bellaire-TX   F  43000.0  888665555.0    4
# 1  291-Berry-Bellaire-TX   F  43000.0  888665555.0    4

# %%
'''Query 6: List the last name, 
    first name of all employees with two or more dependents. (Do NOT use aggregate operator)'''

natural_join2(DE, E, ["Essn"], ["Ssn"])
# Out:
#         Essn Dependent_name Sex_x     Bdate_x Relationship     Fname Minit  \
# 0  123456789          Alice     F  1988-12-30     Daughter      John     B
# 1  123456789      Elizabeth     F  1967-05-05       Spouse      John     B
# 2  123456789        Michael     M  1988-01-04          Son      John     B
# 3  333445555          Alice     F  1986-04-05     Daughter  Franklin     T
# 4  333445555            Joy     F  1958-05-03       Spouse  Franklin     T
# 5  333445555       Theodore     M  1983-10-25          Son  Franklin     T
# 6  987654321          Abner     M  1942-02-28       Spouse  Jennifer     S
#
#      Lname     Bdate_y                 Address Sex_y   Salary     Superssn  \
# 0    Smith  1965-01-09  731-Fondren-Houston-TX     M  30000.0  333445555.0
# 1    Smith  1965-01-09  731-Fondren-Houston-TX     M  30000.0  333445555.0
# 2    Smith  1965-01-09  731-Fondren-Houston-TX     M  30000.0  333445555.0
# 3     Wong  1955-12-08     638-Voss-Houston-TX     M  40000.0  888665555.0
# 4     Wong  1955-12-08     638-Voss-Houston-TX     M  40000.0  888665555.0
# 5     Wong  1955-12-08     638-Voss-Houston-TX     M  40000.0  888665555.0
# 6  Wallace  1941-06-20   291-Berry-Bellaire-TX     F  43000.0  888665555.0
#
#    Dno
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# 5    5
# 6    4

# %%
product(DE, DE)
# Out:
#        Essn_x Dependent_name_x Sex_x     Bdate_x Relationship_x     Essn_y  \
# 0   123456789            Alice     F  1988-12-30       Daughter  123456789
# 1   123456789            Alice     F  1988-12-30       Daughter  123456789
# 2   123456789            Alice     F  1988-12-30       Daughter  123456789
# 3   123456789            Alice     F  1988-12-30       Daughter  333445555
# 4   123456789            Alice     F  1988-12-30       Daughter  333445555
# 5   123456789            Alice     F  1988-12-30       Daughter  333445555
# 6   123456789            Alice     F  1988-12-30       Daughter  987654321
# 7   123456789        Elizabeth     F  1967-05-05         Spouse  123456789
# 8   123456789        Elizabeth     F  1967-05-05         Spouse  123456789
# 9   123456789        Elizabeth     F  1967-05-05         Spouse  123456789
# 10  123456789        Elizabeth     F  1967-05-05         Spouse  333445555
# 11  123456789        Elizabeth     F  1967-05-05         Spouse  333445555
# 12  123456789        Elizabeth     F  1967-05-05         Spouse  333445555
# 13  123456789        Elizabeth     F  1967-05-05         Spouse  987654321
# 14  123456789          Michael     M  1988-01-04            Son  123456789
# 15  123456789          Michael     M  1988-01-04            Son  123456789
# 16  123456789          Michael     M  1988-01-04            Son  123456789
# 17  123456789          Michael     M  1988-01-04            Son  333445555
# 18  123456789          Michael     M  1988-01-04            Son  333445555
# 19  123456789          Michael     M  1988-01-04            Son  333445555
# 20  123456789          Michael     M  1988-01-04            Son  987654321
# 21  333445555            Alice     F  1986-04-05       Daughter  123456789
# 22  333445555            Alice     F  1986-04-05       Daughter  123456789
# 23  333445555            Alice     F  1986-04-05       Daughter  123456789
# 24  333445555            Alice     F  1986-04-05       Daughter  333445555
# 25  333445555            Alice     F  1986-04-05       Daughter  333445555
# 26  333445555            Alice     F  1986-04-05       Daughter  333445555
# 27  333445555            Alice     F  1986-04-05       Daughter  987654321
# 28  333445555              Joy     F  1958-05-03         Spouse  123456789
# 29  333445555              Joy     F  1958-05-03         Spouse  123456789
# 30  333445555              Joy     F  1958-05-03         Spouse  123456789
# 31  333445555              Joy     F  1958-05-03         Spouse  333445555
# 32  333445555              Joy     F  1958-05-03         Spouse  333445555
# 33  333445555              Joy     F  1958-05-03         Spouse  333445555
# 34  333445555              Joy     F  1958-05-03         Spouse  987654321
# 35  333445555         Theodore     M  1983-10-25            Son  123456789
# 36  333445555         Theodore     M  1983-10-25            Son  123456789
# 37  333445555         Theodore     M  1983-10-25            Son  123456789
# 38  333445555         Theodore     M  1983-10-25            Son  333445555
# 39  333445555         Theodore     M  1983-10-25            Son  333445555
# 40  333445555         Theodore     M  1983-10-25            Son  333445555
# 41  333445555         Theodore     M  1983-10-25            Son  987654321
# 42  987654321            Abner     M  1942-02-28         Spouse  123456789
# 43  987654321            Abner     M  1942-02-28         Spouse  123456789
# 44  987654321            Abner     M  1942-02-28         Spouse  123456789
# 45  987654321            Abner     M  1942-02-28         Spouse  333445555
# 46  987654321            Abner     M  1942-02-28         Spouse  333445555
# 47  987654321            Abner     M  1942-02-28         Spouse  333445555
# 48  987654321            Abner     M  1942-02-28         Spouse  987654321
#
#    Dependent_name_y Sex_y     Bdate_y Relationship_y
# 0             Alice     F  1988-12-30       Daughter
# 1         Elizabeth     F  1967-05-05         Spouse
# 2           Michael     M  1988-01-04            Son
# 3             Alice     F  1986-04-05       Daughter
# 4               Joy     F  1958-05-03         Spouse
# 5          Theodore     M  1983-10-25            Son
# 6             Abner     M  1942-02-28         Spouse
# 7             Alice     F  1988-12-30       Daughter
# 8         Elizabeth     F  1967-05-05         Spouse
# 9           Michael     M  1988-01-04            Son
# 10            Alice     F  1986-04-05       Daughter
# 11              Joy     F  1958-05-03         Spouse
# 12         Theodore     M  1983-10-25            Son
# 13            Abner     M  1942-02-28         Spouse
# 14            Alice     F  1988-12-30       Daughter
# 15        Elizabeth     F  1967-05-05         Spouse
# 16          Michael     M  1988-01-04            Son
# 17            Alice     F  1986-04-05       Daughter
# 18              Joy     F  1958-05-03         Spouse
# 19         Theodore     M  1983-10-25            Son
# 20            Abner     M  1942-02-28         Spouse
# 21            Alice     F  1988-12-30       Daughter
# 22        Elizabeth     F  1967-05-05         Spouse
# 23          Michael     M  1988-01-04            Son
# 24            Alice     F  1986-04-05       Daughter
# 25              Joy     F  1958-05-03         Spouse
# 26         Theodore     M  1983-10-25            Son
# 27            Abner     M  1942-02-28         Spouse
# 28            Alice     F  1988-12-30       Daughter
# 29        Elizabeth     F  1967-05-05         Spouse
# 30          Michael     M  1988-01-04            Son
# 31            Alice     F  1986-04-05       Daughter
# 32              Joy     F  1958-05-03         Spouse
# 33         Theodore     M  1983-10-25            Son
# 34            Abner     M  1942-02-28         Spouse
# 35            Alice     F  1988-12-30       Daughter
# 36        Elizabeth     F  1967-05-05         Spouse
# 37          Michael     M  1988-01-04            Son
# 38            Alice     F  1986-04-05       Daughter
# 39              Joy     F  1958-05-03         Spouse
# 40         Theodore     M  1983-10-25            Son
# 41            Abner     M  1942-02-28         Spouse
# 42            Alice     F  1988-12-30       Daughter
# 43        Elizabeth     F  1967-05-05         Spouse
# 44          Michael     M  1988-01-04            Son
# 45            Alice     F  1986-04-05       Daughter
# 46              Joy     F  1958-05-03         Spouse
# 47         Theodore     M  1983-10-25            Son
# 48            Abner     M  1942-02-28         Spouse
