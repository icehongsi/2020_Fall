# %% [markdown]
# # Relational Algebra Opeartors

# %% [markdown]
# ***This jupyter notebook and all the codes are written by Kirack Sohn and copyrighted!***

# %% [markdown]
# ## DB setup

# %%
EMPLOYEE_csv = 'Fname,Minit,Lname,Ssn,Bdate,Address,Sex,Salary,Superssn,Dno\r\nJohn,B,Smith,123456789,1965-01-09,731-Fondren-Houston-TX,M,30000.00,333445555,5\r\nFranklin,T,Wong,333445555,1955-12-08,638-Voss-Houston-TX,M,40000.00,888665555,5\r\nJoyce,A,English,453453453,1972-07-31,5631-Rice-Houston-TX,F,25000.00,333445555,5\r\nRamesh,K,Narayan,666884444,1962-09-15,975-Fire-Oak-Humble-TX,M,38000.00,333445555,5\r\nJames,E,Borg,888665555,1937-11-10,450-Stone-Houston-TX,M,55000.00,,1\r\nJennifer,S,Wallace,987654321,1941-06-20,291-Berry-Bellaire-TX,F,43000.00,888665555,4\r\nAhmad,V,Jabbar,987987987,1969-03-29,980-Dallas-Houston-TX,M,25000.00,987654321,4\r\nAlicia,J,Zelaya,999887777,1968-01-19,3321-Castle-Spring-TX,F,25000.00,987654321,4\r\n'
DEPARTMENT_csv = 'Dname,Dnumber,Mgrssn,Mgrstartdate\r\nHeadquarters,1,888665555,1981-06-19\r\nAdministration,4,987654321,1995-01-01\r\nResearch,5,333445555,1988-05-22\r\n'
DEPT_LOCATIONS_csv = 'Dnumber,Dlocation\r\n1,Houston\r\n4,Stafford\r\n5,Bellaire\r\n5,Houston\r\n5,Sugarland\r\n'
PROJECT_csv = 'Pname,Pnumber,Plocation,Dnum\r\nProductX,1,Bellaire,5\r\nProductY,2,Sugarland,5\r\nProductZ,3,Houston,5\r\nComputerization,10,Stafford,4\r\nReorganization,20,Houston,1\r\nNewbenefits,30,Stafford,4\r\n'
WORKS_ON_csv = 'Essn,Pno,Hours\r\n123456789,1,32.5\r\n123456789,2,7.5\r\n333445555,2,10.0\r\n333445555,3,10.0\r\n333445555,10,10.0\r\n333445555,20,10.0\r\n453453453,1,20.0\r\n453453453,2,20.0\r\n666884444,3,40.0\r\n888665555,20,\r\n987654321,20,15.0\r\n987654321,30,20.0\r\n987987987,10,35.0\r\n987987987,30,5.0\r\n999887777,10,10.0\r\n999887777,30,30.0\r\n'
DEPENDENT_csv = 'Essn,Dependent_name,Sex,Bdate,Relationship\r\n123456789,Alice,F,1988-12-30,Daughter\r\n123456789,Elizabeth,F,1967-05-05,Spouse\r\n123456789,Michael,M,1988-01-04,Son\r\n333445555,Alice,F,1986-04-05,Daughter\r\n333445555,Joy,F,1958-05-03,Spouse\r\n333445555,Theodore,M,1983-10-25,Son\r\n987654321,Abner,M,1942-02-28,Spouse\r\n'

# import packages

import pandas as pd
from io import StringIO 
import re

# Tables
EMPLOYEE = pd.read_csv(StringIO(EMPLOYEE_csv))
DEPARTMENT = pd.read_csv(StringIO(DEPARTMENT_csv))
DEPT_LOCATIONS = pd.read_csv(StringIO(DEPT_LOCATIONS_csv))
PROJECT = pd.read_csv(StringIO(PROJECT_csv))
WORKS_ON = pd.read_csv(StringIO(WORKS_ON_csv))
DEPENDENT = pd.read_csv(StringIO(DEPENDENT_csv))

# short_names for Tables
E = EMPLOYEE
D = DEPARTMENT
DL = DEPT_LOCATIONS
P = PROJECT
WO = WORKS_ON
DE = DEPENDENT

# %% [markdown]
# ## Renaming

# %%
def rename(R, C):
    return R.rename(columns=C)

# %% [markdown]
# ### Renaming Examples
#
# - Rename Pnumber to Pno
# - Note that P is NOT changed

# %%
P
# Out:
#              Pname  Pnumber  Plocation  Dnum
# 0         ProductX        1   Bellaire     5
# 1         ProductY        2  Sugarland     5
# 2         ProductZ        3    Houston     5
# 3  Computerization       10   Stafford     4
# 4   Reorganization       20    Houston     1
# 5      Newbenefits       30   Stafford     4

# %%
P.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Pname      6 non-null      object
#  1   Pnumber    6 non-null      int64
#  2   Plocation  6 non-null      object
#  3   Dnum       6 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 320.0+ bytes

# %%
rename(P, {'Pnumber':'Pno'})
# Out:
#              Pname  Pno  Plocation  Dnum
# 0         ProductX    1   Bellaire     5
# 1         ProductY    2  Sugarland     5
# 2         ProductZ    3    Houston     5
# 3  Computerization   10   Stafford     4
# 4   Reorganization   20    Houston     1
# 5      Newbenefits   30   Stafford     4

# %%
rename(P, {'Pnumber':'Pno', 'Dnum': 'Dno'})
# Out:
#              Pname  Pno  Plocation  Dno
# 0         ProductX    1   Bellaire    5
# 1         ProductY    2  Sugarland    5
# 2         ProductZ    3    Houston    5
# 3  Computerization   10   Stafford    4
# 4   Reorganization   20    Houston    1
# 5      Newbenefits   30   Stafford    4

# %%
# Note that P is unchnaged
P
# Out:
#              Pname  Pnumber  Plocation  Dnum
# 0         ProductX        1   Bellaire     5
# 1         ProductY        2  Sugarland     5
# 2         ProductZ        3    Houston     5
# 3  Computerization       10   Stafford     4
# 4   Reorganization       20    Houston     1
# 5      Newbenefits       30   Stafford     4

# %%
P.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Pname      6 non-null      object
#  1   Pnumber    6 non-null      int64
#  2   Plocation  6 non-null      object
#  3   Dnum       6 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 320.0+ bytes

# %% [markdown]
# ## Selection
#
# - logical operator: &, |, ~ (and, or, not)
# - arithmetic operators: >, <, >=, <=, ==, !=
# - data types: String, Numbers, Date as String
# - Date Format: 2020-10-01

# %%
def select(R, C):
    # The following substitution may NOT work 
    # when column name is equal to a string value in C
    tokens = re.split(r'(\W+)', C)
    new_tokens = ["R." + token  if token in R.columns else token \
                  for token in tokens] 
    selected = eval(''.join(new_tokens))
    return R[selected].reset_index(drop=True)

# %% [markdown]
# ### Selection Examples
#
# - Condition as String

# %%
select(D, "Dname == 'Headquarters'")
# Out:
#           Dname  Dnumber     Mgrssn Mgrstartdate
# 0  Headquarters        1  888665555   1981-06-19

# %%
select(D, "(Dnumber == 1) | (Dnumber == 4)")
# Out:
#             Dname  Dnumber     Mgrssn Mgrstartdate
# 0    Headquarters        1  888665555   1981-06-19
# 1  Administration        4  987654321   1995-01-01

# %% [markdown]
# - Note parenthesis enclosing comparison expression due to operator precedence

# %%
select(E, "(Salary >= 35000) & (Salary <= 40000)")
# Out:
#       Fname Minit    Lname        Ssn       Bdate                 Address Sex  \
# 0  Franklin     T     Wong  333445555  1955-12-08     638-Voss-Houston-TX   M
# 1    Ramesh     K  Narayan  666884444  1962-09-15  975-Fire-Oak-Humble-TX   M
#
#     Salary     Superssn  Dno
# 0  40000.0  888665555.0    5
# 1  38000.0  333445555.0    5

# %% [markdown]
# Note that comparison is not date comparison, but string comparison

# %%
select(E, "Bdate >= '1960-01-01'")
# Out:
#     Fname Minit    Lname        Ssn       Bdate                 Address Sex  \
# 0    John     B    Smith  123456789  1965-01-09  731-Fondren-Houston-TX   M
# 1   Joyce     A  English  453453453  1972-07-31    5631-Rice-Houston-TX   F
# 2  Ramesh     K  Narayan  666884444  1962-09-15  975-Fire-Oak-Humble-TX   M
# 3   Ahmad     V   Jabbar  987987987  1969-03-29   980-Dallas-Houston-TX   M
# 4  Alicia     J   Zelaya  999887777  1968-01-19   3321-Castle-Spring-TX   F
#
#     Salary     Superssn  Dno
# 0  30000.0  333445555.0    5
# 1  25000.0  333445555.0    5
# 2  38000.0  333445555.0    5
# 3  25000.0  987654321.0    4
# 4  25000.0  987654321.0    4

# %% [markdown]
# ## Projection

# %%
def project(R, C):
    return R[C].drop_duplicates().reset_index(drop=True)

# %% [markdown]
# ### Projection Examples

# %%
project(WO, ['Essn'])
# Out:
#         Essn
# 0  123456789
# 1  333445555
# 2  453453453
# 3  666884444
# 4  888665555
# 5  987654321
# 6  987987987
# 7  999887777

# %%
# project(dNumber)(select(dLocation==Huston)(DEPT_LOCATIONS)
project(
  select(
      DL,
      "Dlocation == 'Houston'"
  ),
  ['Dnumber']
)
# Out:
#    Dnumber
# 0        1
# 1        5

# %% [markdown]
# ## Union

# %%
def union(R, S):
    S.columns = R.columns
    T = pd.concat([R, S], ignore_index=True)
    T = T.drop_duplicates().reset_index(drop=True)
    return T

# %%
union(project(E, ['Ssn']), project(D,['Mgrssn']))
# Out:
#          Ssn
# 0  123456789
# 1  333445555
# 2  453453453
# 3  666884444
# 4  888665555
# 5  987654321
# 6  987987987
# 7  999887777

# %% [markdown]
# ## Intersection

# %%
def intersect(R, S):
    S.columns = R.columns
    return R.merge(S).reset_index(drop=True)

# %% [markdown]
# ### Intersection Examples

# %%
intersect(project(E, ['Ssn']), project(D,['Mgrssn']))
# Out:
#          Ssn
# 0  333445555
# 1  888665555
# 2  987654321

# %% [markdown]
# ## Difference

# %%
def minus(R, S):
    S.columns = R.columns
    return pd.concat([R, S, S]).drop_duplicates(keep=False).reset_index(drop=True)

# %% [markdown]
# ### Difference examples

# %%
minus(project(E, ['Ssn']), project(D,['Mgrssn']))
# Out:
#          Ssn
# 0  123456789
# 1  453453453
# 2  666884444
# 3  987987987
# 4  999887777

# %% [markdown]
# ## Cartesian Product

# %%
def product(R, S):
    """Determine Cartesian product of two data frames."""
    key = 'key'
    while key in R.columns or key in S.columns:
        key = '_' + key
    key_d = {key: 0}
    return pd.merge(R.assign(**key_d), S.assign(**key_d), on=key)\
           .drop(key, axis=1).reset_index(drop=True)

# %% [markdown]
# ### Cartesian Product Examples

# %%
product(E, D)
# Out:
#        Fname Minit    Lname        Ssn       Bdate                 Address  \
# 0       John     B    Smith  123456789  1965-01-09  731-Fondren-Houston-TX
# 1       John     B    Smith  123456789  1965-01-09  731-Fondren-Houston-TX
# 2       John     B    Smith  123456789  1965-01-09  731-Fondren-Houston-TX
# 3   Franklin     T     Wong  333445555  1955-12-08     638-Voss-Houston-TX
# 4   Franklin     T     Wong  333445555  1955-12-08     638-Voss-Houston-TX
# 5   Franklin     T     Wong  333445555  1955-12-08     638-Voss-Houston-TX
# 6      Joyce     A  English  453453453  1972-07-31    5631-Rice-Houston-TX
# 7      Joyce     A  English  453453453  1972-07-31    5631-Rice-Houston-TX
# 8      Joyce     A  English  453453453  1972-07-31    5631-Rice-Houston-TX
# 9     Ramesh     K  Narayan  666884444  1962-09-15  975-Fire-Oak-Humble-TX
# 10    Ramesh     K  Narayan  666884444  1962-09-15  975-Fire-Oak-Humble-TX
# 11    Ramesh     K  Narayan  666884444  1962-09-15  975-Fire-Oak-Humble-TX
# 12     James     E     Borg  888665555  1937-11-10    450-Stone-Houston-TX
# 13     James     E     Borg  888665555  1937-11-10    450-Stone-Houston-TX
# 14     James     E     Borg  888665555  1937-11-10    450-Stone-Houston-TX
# 15  Jennifer     S  Wallace  987654321  1941-06-20   291-Berry-Bellaire-TX
# 16  Jennifer     S  Wallace  987654321  1941-06-20   291-Berry-Bellaire-TX
# 17  Jennifer     S  Wallace  987654321  1941-06-20   291-Berry-Bellaire-TX
# 18     Ahmad     V   Jabbar  987987987  1969-03-29   980-Dallas-Houston-TX
# 19     Ahmad     V   Jabbar  987987987  1969-03-29   980-Dallas-Houston-TX
# 20     Ahmad     V   Jabbar  987987987  1969-03-29   980-Dallas-Houston-TX
# 21    Alicia     J   Zelaya  999887777  1968-01-19   3321-Castle-Spring-TX
# 22    Alicia     J   Zelaya  999887777  1968-01-19   3321-Castle-Spring-TX
# 23    Alicia     J   Zelaya  999887777  1968-01-19   3321-Castle-Spring-TX
#
#    Sex   Salary     Superssn  Dno           Dname  Dnumber     Mgrssn  \
# 0    M  30000.0  333445555.0    5    Headquarters        1  888665555
# 1    M  30000.0  333445555.0    5  Administration        4  987654321
# 2    M  30000.0  333445555.0    5        Research        5  333445555
# 3    M  40000.0  888665555.0    5    Headquarters        1  888665555
# 4    M  40000.0  888665555.0    5  Administration        4  987654321
# 5    M  40000.0  888665555.0    5        Research        5  333445555
# 6    F  25000.0  333445555.0    5    Headquarters        1  888665555
# 7    F  25000.0  333445555.0    5  Administration        4  987654321
# 8    F  25000.0  333445555.0    5        Research        5  333445555
# 9    M  38000.0  333445555.0    5    Headquarters        1  888665555
# 10   M  38000.0  333445555.0    5  Administration        4  987654321
# 11   M  38000.0  333445555.0    5        Research        5  333445555
# 12   M  55000.0          NaN    1    Headquarters        1  888665555
# 13   M  55000.0          NaN    1  Administration        4  987654321
# 14   M  55000.0          NaN    1        Research        5  333445555
# 15   F  43000.0  888665555.0    4    Headquarters        1  888665555
# 16   F  43000.0  888665555.0    4  Administration        4  987654321
# 17   F  43000.0  888665555.0    4        Research        5  333445555
# 18   M  25000.0  987654321.0    4    Headquarters        1  888665555
# 19   M  25000.0  987654321.0    4  Administration        4  987654321
# 20   M  25000.0  987654321.0    4        Research        5  333445555
# 21   F  25000.0  987654321.0    4    Headquarters        1  888665555
# 22   F  25000.0  987654321.0    4  Administration        4  987654321
# 23   F  25000.0  987654321.0    4        Research        5  333445555
#
#    Mgrstartdate
# 0    1981-06-19
# 1    1995-01-01
# 2    1988-05-22
# 3    1981-06-19
# 4    1995-01-01
# 5    1988-05-22
# 6    1981-06-19
# 7    1995-01-01
# 8    1988-05-22
# 9    1981-06-19
# 10   1995-01-01
# 11   1988-05-22
# 12   1981-06-19
# 13   1995-01-01
# 14   1988-05-22
# 15   1981-06-19
# 16   1995-01-01
# 17   1988-05-22
# 18   1981-06-19
# 19   1995-01-01
# 20   1988-05-22
# 21   1981-06-19
# 22   1995-01-01
# 23   1988-05-22

# %% [markdown]
# ## Joins

# %%
def natural_join(R, S):
    return pd.merge(R, S).reset_index(drop=True)

# %% [markdown]
# ### Natural Join Examples

# %%
print(D, DL, sep = "\n\n")
natural_join(D, D)
# Out:
#             Dname  Dnumber     Mgrssn Mgrstartdate
# 0    Headquarters        1  888665555   1981-06-19
# 1  Administration        4  987654321   1995-01-01
# 2        Research        5  333445555   1988-05-22
#
#    Dnumber  Dlocation
# 0        1    Houston
# 1        4   Stafford
# 2        5   Bellaire
# 3        5    Houston
# 4        5  Sugarland
#             Dname  Dnumber     Mgrssn Mgrstartdate
# 0    Headquarters        1  888665555   1981-06-19
# 1  Administration        4  987654321   1995-01-01
# 2        Research        5  333445555   1988-05-22

# %%
natural_join(D, DL)
# Out:
#             Dname  Dnumber     Mgrssn Mgrstartdate  Dlocation
# 0    Headquarters        1  888665555   1981-06-19    Houston
# 1  Administration        4  987654321   1995-01-01   Stafford
# 2        Research        5  333445555   1988-05-22   Bellaire
# 3        Research        5  333445555   1988-05-22    Houston
# 4        Research        5  333445555   1988-05-22  Sugarland

# %%
natural_join(DL, D)
# Out:
#    Dnumber  Dlocation           Dname     Mgrssn Mgrstartdate
# 0        1    Houston    Headquarters  888665555   1981-06-19
# 1        4   Stafford  Administration  987654321   1995-01-01
# 2        5   Bellaire        Research  333445555   1988-05-22
# 3        5    Houston        Research  333445555   1988-05-22
# 4        5  Sugarland        Research  333445555   1988-05-22

# %%
def natural_join2(R, S, keys_R, keys_S):
    return pd.merge(R, S, left_on=keys_R, right_on=keys_S)\
           .drop(keys_S, axis=1).reset_index(drop=True)

# %%
natural_join2(E, D, ['Dno', 'Ssn'], ['Dnumber', 'Mgrssn'])
# Out:
#       Fname Minit    Lname        Ssn       Bdate                Address Sex  \
# 0  Franklin     T     Wong  333445555  1955-12-08    638-Voss-Houston-TX   M
# 1     James     E     Borg  888665555  1937-11-10   450-Stone-Houston-TX   M
# 2  Jennifer     S  Wallace  987654321  1941-06-20  291-Berry-Bellaire-TX   F
#
#     Salary     Superssn  Dno           Dname Mgrstartdate
# 0  40000.0  888665555.0    5        Research   1988-05-22
# 1  55000.0          NaN    1    Headquarters   1981-06-19
# 2  43000.0  888665555.0    4  Administration   1995-01-01

# %% [markdown]
# ### Equi-join Examples

# %%
def equi_join(R, S, keys_R, keys_S):
    return pd.merge(R, S, left_on = keys_R, right_on=keys_S).reset_index(drop=True)

# %%
equi_join(E, D, ['Dno', 'Ssn'], ['Dnumber', 'Mgrssn'])
# Out:
#       Fname Minit    Lname        Ssn       Bdate                Address Sex  \
# 0  Franklin     T     Wong  333445555  1955-12-08    638-Voss-Houston-TX   M
# 1     James     E     Borg  888665555  1937-11-10   450-Stone-Houston-TX   M
# 2  Jennifer     S  Wallace  987654321  1941-06-20  291-Berry-Bellaire-TX   F
#
#     Salary     Superssn  Dno           Dname  Dnumber     Mgrssn Mgrstartdate
# 0  40000.0  888665555.0    5        Research        5  333445555   1988-05-22
# 1  55000.0          NaN    1    Headquarters        1  888665555   1981-06-19
# 2  43000.0  888665555.0    4  Administration        4  987654321   1995-01-01

# %%
equi_join(D, DL, ['Dnumber'], ['Dnumber'])
# Out:
#             Dname  Dnumber     Mgrssn Mgrstartdate  Dlocation
# 0    Headquarters        1  888665555   1981-06-19    Houston
# 1  Administration        4  987654321   1995-01-01   Stafford
# 2        Research        5  333445555   1988-05-22   Bellaire
# 3        Research        5  333445555   1988-05-22    Houston
# 4        Research        5  333445555   1988-05-22  Sugarland

# %% [markdown]
# ### Outer-join examples

# %%
def left_outer_join(R, S):
        return pd.merge(R, S, how='left').reset_index(drop=True)

# %%
left_outer_join(E, E)
# Out:
#       Fname Minit    Lname        Ssn       Bdate                 Address Sex  \
# 0      John     B    Smith  123456789  1965-01-09  731-Fondren-Houston-TX   M
# 1  Franklin     T     Wong  333445555  1955-12-08     638-Voss-Houston-TX   M
# 2     Joyce     A  English  453453453  1972-07-31    5631-Rice-Houston-TX   F
# 3    Ramesh     K  Narayan  666884444  1962-09-15  975-Fire-Oak-Humble-TX   M
# 4     James     E     Borg  888665555  1937-11-10    450-Stone-Houston-TX   M
# 5  Jennifer     S  Wallace  987654321  1941-06-20   291-Berry-Bellaire-TX   F
# 6     Ahmad     V   Jabbar  987987987  1969-03-29   980-Dallas-Houston-TX   M
# 7    Alicia     J   Zelaya  999887777  1968-01-19   3321-Castle-Spring-TX   F
#
#     Salary     Superssn  Dno
# 0  30000.0  333445555.0    5
# 1  40000.0  888665555.0    5
# 2  25000.0  333445555.0    5
# 3  38000.0  333445555.0    5
# 4  55000.0          NaN    1
# 5  43000.0  888665555.0    4
# 6  25000.0  987654321.0    4
# 7  25000.0  987654321.0    4

# %%
def right_outer_join(R, S):
        return pd.merge(R, S, how='right').reset_index(drop=True)

# %%
right_outer_join(D, DL)
# Out:
#             Dname  Dnumber     Mgrssn Mgrstartdate  Dlocation
# 0    Headquarters        1  888665555   1981-06-19    Houston
# 1  Administration        4  987654321   1995-01-01   Stafford
# 2        Research        5  333445555   1988-05-22   Bellaire
# 3        Research        5  333445555   1988-05-22    Houston
# 4        Research        5  333445555   1988-05-22  Sugarland

# %%
def left_outer_join(R, S, keys_R, keys_S):
    return pd.merge(R, S, how='left', left_on=keys_R, right_on=keys_S)\
           .reset_index(drop=True)

# %%
left_outer_join(E, D, ['Dno'], ['Dnumber'])
# Out:
#       Fname Minit    Lname        Ssn       Bdate                 Address Sex  \
# 0      John     B    Smith  123456789  1965-01-09  731-Fondren-Houston-TX   M
# 1  Franklin     T     Wong  333445555  1955-12-08     638-Voss-Houston-TX   M
# 2     Joyce     A  English  453453453  1972-07-31    5631-Rice-Houston-TX   F
# 3    Ramesh     K  Narayan  666884444  1962-09-15  975-Fire-Oak-Humble-TX   M
# 4     James     E     Borg  888665555  1937-11-10    450-Stone-Houston-TX   M
# 5  Jennifer     S  Wallace  987654321  1941-06-20   291-Berry-Bellaire-TX   F
# 6     Ahmad     V   Jabbar  987987987  1969-03-29   980-Dallas-Houston-TX   M
# 7    Alicia     J   Zelaya  999887777  1968-01-19   3321-Castle-Spring-TX   F
#
#     Salary     Superssn  Dno           Dname  Dnumber     Mgrssn Mgrstartdate
# 0  30000.0  333445555.0    5        Research        5  333445555   1988-05-22
# 1  40000.0  888665555.0    5        Research        5  333445555   1988-05-22
# 2  25000.0  333445555.0    5        Research        5  333445555   1988-05-22
# 3  38000.0  333445555.0    5        Research        5  333445555   1988-05-22
# 4  55000.0          NaN    1    Headquarters        1  888665555   1981-06-19
# 5  43000.0  888665555.0    4  Administration        4  987654321   1995-01-01
# 6  25000.0  987654321.0    4  Administration        4  987654321   1995-01-01
# 7  25000.0  987654321.0    4  Administration        4  987654321   1995-01-01

# %%
left_outer_join(E, E, ['Superssn'], ['Ssn'])
# Out:
#     Fname_x Minit_x  Lname_x      Ssn_x     Bdate_x               Address_x  \
# 0      John       B    Smith  123456789  1965-01-09  731-Fondren-Houston-TX
# 1  Franklin       T     Wong  333445555  1955-12-08     638-Voss-Houston-TX
# 2     Joyce       A  English  453453453  1972-07-31    5631-Rice-Houston-TX
# 3    Ramesh       K  Narayan  666884444  1962-09-15  975-Fire-Oak-Humble-TX
# 4     James       E     Borg  888665555  1937-11-10    450-Stone-Houston-TX
# 5  Jennifer       S  Wallace  987654321  1941-06-20   291-Berry-Bellaire-TX
# 6     Ahmad       V   Jabbar  987987987  1969-03-29   980-Dallas-Houston-TX
# 7    Alicia       J   Zelaya  999887777  1968-01-19   3321-Castle-Spring-TX
#
#   Sex_x  Salary_x   Superssn_x  Dno_x   Fname_y Minit_y  Lname_y        Ssn_y  \
# 0     M   30000.0  333445555.0      5  Franklin       T     Wong  333445555.0
# 1     M   40000.0  888665555.0      5     James       E     Borg  888665555.0
# 2     F   25000.0  333445555.0      5  Franklin       T     Wong  333445555.0
# 3     M   38000.0  333445555.0      5  Franklin       T     Wong  333445555.0
# 4     M   55000.0          NaN      1       NaN     NaN      NaN          NaN
# 5     F   43000.0  888665555.0      4     James       E     Borg  888665555.0
# 6     M   25000.0  987654321.0      4  Jennifer       S  Wallace  987654321.0
# 7     F   25000.0  987654321.0      4  Jennifer       S  Wallace  987654321.0
#
#       Bdate_y              Address_y Sex_y  Salary_y   Superssn_y  Dno_y
# 0  1955-12-08    638-Voss-Houston-TX     M   40000.0  888665555.0    5.0
# 1  1937-11-10   450-Stone-Houston-TX     M   55000.0          NaN    1.0
# 2  1955-12-08    638-Voss-Houston-TX     M   40000.0  888665555.0    5.0
# 3  1955-12-08    638-Voss-Houston-TX     M   40000.0  888665555.0    5.0
# 4         NaN                    NaN   NaN       NaN          NaN    NaN
# 5  1937-11-10   450-Stone-Houston-TX     M   55000.0          NaN    1.0
# 6  1941-06-20  291-Berry-Bellaire-TX     F   43000.0  888665555.0    4.0
# 7  1941-06-20  291-Berry-Bellaire-TX     F   43000.0  888665555.0    4.0

# %% [markdown]
# ## Division

# %%
def division(R, S):
    Z = set(R.columns) #첫번째
    X = set(S.columns) #두번째
    assert X <= Z
    Y = pd.Index(Z - X)
    T1 = project(R, Y)
    T2 = project(minus(product(T1, S), R), Y)
    T = minus(T1, T2)
    return T.reset_index(drop=True)

# %% [markdown]
# ### Division Examples

# %%
U = project(WO, ['Essn', 'Pno'])

# %%
V1 = rename(project(select(P, "Plocation == 'Houston'"), ['Pnumber']), {'Pnumber':'Pno'})

# %%
print(U.columns) # >> Z, 2개
U
# Out:
# Index(['Essn', 'Pno'], dtype='object')
#          Essn  Pno
# 0   123456789    1
# 1   123456789    2
# 2   333445555    2
# 3   333445555    3
# 4   333445555   10
# 5   333445555   20
# 6   453453453    1
# 7   453453453    2
# 8   666884444    3
# 9   888665555   20
# 10  987654321   20
# 11  987654321   30
# 12  987987987   10
# 13  987987987   30
# 14  999887777   10
# 15  999887777   30

# %%
print(V1.columns) # >> X, 1개
V1
# Out:
# Index(['Pno'], dtype='object')
#    Pno
# 0    3
# 1   20

# %%
division(U, V1)
# Out:
#         Essn
# 0  333445555

# %%
V2 = pd.DataFrame({'Pno':[1,2]})

# %%
division(U, V2)
# Out:
#         Essn
# 0  123456789
# 1  453453453

# %% [markdown]
# #### Q. Retrieve the names of all employees in department 5 who work more than 10 hours per week on the ProductX project.

# %%
project(
    natural_join2(
        natural_join2(
            select(E, "Dno == 5"),
            select(WO, "Hours > 10"),
            ["Ssn"], ["Essn"]
        ),
        select(
            P,
            "Pname == 'ProductX'"
        ),
        ["Pno"],
        ["Pnumber"]
    ),
    ["Fname", "Lname"]
)
# Out:
#    Fname    Lname
# 0   John    Smith
# 1  Joyce  English

# %% [markdown]
# ## Aggregation
#
# F = {"Salary": "sum", "Sex": "count"}
#
# Limitation: Only one aggregate function is allowed per attribute
#
# Later, the following will be implemented:
# F = {"Salary": ["count", "sum"], "Salary": "sum", "Sex": "count"}

# %%
def aggregate(R, F):
    s = '{'
    for e in F:
        if F[e] == "count": s += "'" + e + "': pd.Series.nunique, "
        elif F[e] == "sum": s += "'" + e + "': pd.Series.sum, "
        elif F[e] == "average": s += "'" + e +  "': pd.Series.mean, "
        elif F[e] == "min": s += "'" + e +  "': pd.Series.min, "
        elif F[e] == "max": s += "'" + e +  "': pd.Series.max, "
        else: assert False, "not supported"
    s += '}'  
    print("R.agg(" + s +")")
    return eval("R.agg(" + s +")").to_frame().transpose()

# %%
aggregate(E, {"Salary" : "sum"})
# Out:
# R.agg({'Salary': pd.Series.sum, })
#      Salary
# 0  281000.0

# %%
aggregate(E, {"Salary" : "sum", "Sex" : "count"})
# Out:
# R.agg({'Salary': pd.Series.sum, 'Sex': pd.Series.nunique, })
#      Salary  Sex
# 0  281000.0  2.0

# %%
def aggregate2(R, G, F):
    s = '{'
    for e in F:
        if F[e] == "count": s += "'" + e + "': pd.Series.nunique, "
        elif F[e] == "sum": s += "'" + e + "': pd.Series.sum, "
        elif F[e] == "average": s += "'" + e +  "': pd.Series.mean, "
        elif F[e] == "min": s += "'" + e +  "': pd.Series.min, "
        elif F[e] == "max": s += "'" + e +  "': pd.Series.max, "
        else: assert False, "not supported"
    s += '}'  
    print("R.groupby(by=G, as_index=False).agg(" + s +")")
    return eval("R.groupby(by=G, as_index=False).agg(" + s +")")

# %%
aggregate2(E, ["Dno"], {"Salary" : "sum"})
# Out:
# R.groupby(by=G, as_index=False).agg({'Salary': pd.Series.sum, })
#    Dno    Salary
# 0    1   55000.0
# 1    4   93000.0
# 2    5  133000.0

# %%
aggregate2(E, ["Dno"], {"Salary" : "sum", "Sex" : "count"})
# Out:
# R.groupby(by=G, as_index=False).agg({'Salary': pd.Series.sum, 'Sex': pd.Series.nunique, })
#    Dno    Salary  Sex
# 0    1   55000.0    1
# 1    4   93000.0    2
# 2    5  133000.0    2

# %% [markdown]
# #### Q. Retrieve the names of the highest paid employees in each department.

# %%
project(
    natural_join2(
        natural_join(
            E,
            aggregate2(E, ["Dno"], {"Salary" : "max"})
        ),
        D,
        ["Dno"],
        ["Dnumber"]
    ),
    ["Dname", "Fname", "Lname", "Salary"]
)
# Out:
# R.groupby(by=G, as_index=False).agg({'Salary': pd.Series.max, })
#             Dname     Fname    Lname   Salary
# 0        Research  Franklin     Wong  40000.0
# 1    Headquarters     James     Borg  55000.0
# 2  Administration  Jennifer  Wallace  43000.0

# %% [markdown]
# ## Reorganization Project에 참여하는 직원의 이름은?

# %%
T = product(product(E, WO), P)
T
# Out:
#       Fname Minit   Lname        Ssn  ...            Pname Pnumber  Plocation  Dnum
# 0      John     B   Smith  123456789  ...         ProductX       1   Bellaire     5
# 1      John     B   Smith  123456789  ...         ProductY       2  Sugarland     5
# 2      John     B   Smith  123456789  ...         ProductZ       3    Houston     5
# 3      John     B   Smith  123456789  ...  Computerization      10   Stafford     4
# 4      John     B   Smith  123456789  ...   Reorganization      20    Houston     1
# ..      ...   ...     ...        ...  ...              ...     ...        ...   ...
# 763  Alicia     J  Zelaya  999887777  ...         ProductY       2  Sugarland     5
# 764  Alicia     J  Zelaya  999887777  ...         ProductZ       3    Houston     5
# 765  Alicia     J  Zelaya  999887777  ...  Computerization      10   Stafford     4
# 766  Alicia     J  Zelaya  999887777  ...   Reorganization      20    Houston     1
# 767  Alicia     J  Zelaya  999887777  ...      Newbenefits      30   Stafford     4
#
# [768 rows x 17 columns]

# %%
U = select(T, '(Ssn == Essn) & (Pno == Pnumber) & (Pname == "Reorganization")')
U
# Out:
#       Fname Minit    Lname        Ssn  ...           Pname Pnumber Plocation  Dnum
# 0  Franklin     T     Wong  333445555  ...  Reorganization      20   Houston     1
# 1     James     E     Borg  888665555  ...  Reorganization      20   Houston     1
# 2  Jennifer     S  Wallace  987654321  ...  Reorganization      20   Houston     1
#
# [3 rows x 17 columns]

# %%
project(U, ['Fname', 'Lname'])
# Out:
#       Fname    Lname
# 0  Franklin     Wong
# 1     James     Borg
# 2  Jennifer  Wallace

# %% [markdown]
# # James Borg 보다 연봉이 더 작은 직원의 이름은?

# %%
S = project(
    select(
        E,
        "(Fname == 'James') & (Lname == 'Borg')"
    ),
    ['Salary']
)
S
# Out:
#     Salary
# 0  55000.0

# %%
project(select(product(S, E), "Salary_x > Salary_y"), ['Fname', 'Lname'])
# Out:
#       Fname    Lname
# 0      John    Smith
# 1  Franklin     Wong
# 2     Joyce  English
# 3    Ramesh  Narayan
# 4  Jennifer  Wallace
# 5     Ahmad   Jabbar
# 6    Alicia   Zelaya

# %%
product(S,E)
# Out:
#    Salary_x     Fname Minit    Lname  ...  Sex Salary_y     Superssn Dno
# 0   55000.0      John     B    Smith  ...    M  30000.0  333445555.0   5
# 1   55000.0  Franklin     T     Wong  ...    M  40000.0  888665555.0   5
# 2   55000.0     Joyce     A  English  ...    F  25000.0  333445555.0   5
# 3   55000.0    Ramesh     K  Narayan  ...    M  38000.0  333445555.0   5
# 4   55000.0     James     E     Borg  ...    M  55000.0          NaN   1
# 5   55000.0  Jennifer     S  Wallace  ...    F  43000.0  888665555.0   4
# 6   55000.0     Ahmad     V   Jabbar  ...    M  25000.0  987654321.0   4
# 7   55000.0    Alicia     J   Zelaya  ...    F  25000.0  987654321.0   4
#
# [8 rows x 11 columns]

# %%
E
# Out:
#       Fname Minit    Lname        Ssn       Bdate                 Address Sex  \
# 0      John     B    Smith  123456789  1965-01-09  731-Fondren-Houston-TX   M
# 1  Franklin     T     Wong  333445555  1955-12-08     638-Voss-Houston-TX   M
# 2     Joyce     A  English  453453453  1972-07-31    5631-Rice-Houston-TX   F
# 3    Ramesh     K  Narayan  666884444  1962-09-15  975-Fire-Oak-Humble-TX   M
# 4     James     E     Borg  888665555  1937-11-10    450-Stone-Houston-TX   M
# 5  Jennifer     S  Wallace  987654321  1941-06-20   291-Berry-Bellaire-TX   F
# 6     Ahmad     V   Jabbar  987987987  1969-03-29   980-Dallas-Houston-TX   M
# 7    Alicia     J   Zelaya  999887777  1968-01-19   3321-Castle-Spring-TX   F
#
#     Salary     Superssn  Dno
# 0  30000.0  333445555.0    5
# 1  40000.0  888665555.0    5
# 2  25000.0  333445555.0    5
# 3  38000.0  333445555.0    5
# 4  55000.0          NaN    1
# 5  43000.0  888665555.0    4
# 6  25000.0  987654321.0    4
# 7  25000.0  987654321.0    4

# %%
D
# Out:
#             Dname  Dnumber     Mgrssn Mgrstartdate
# 0    Headquarters        1  888665555   1981-06-19
# 1  Administration        4  987654321   1995-01-01
# 2        Research        5  333445555   1988-05-22

# %%
natural_join2(E, D, "Dno", "Dnumber")
# Out:
#       Fname Minit    Lname        Ssn       Bdate                 Address Sex  \
# 0      John     B    Smith  123456789  1965-01-09  731-Fondren-Houston-TX   M
# 1  Franklin     T     Wong  333445555  1955-12-08     638-Voss-Houston-TX   M
# 2     Joyce     A  English  453453453  1972-07-31    5631-Rice-Houston-TX   F
# 3    Ramesh     K  Narayan  666884444  1962-09-15  975-Fire-Oak-Humble-TX   M
# 4     James     E     Borg  888665555  1937-11-10    450-Stone-Houston-TX   M
# 5  Jennifer     S  Wallace  987654321  1941-06-20   291-Berry-Bellaire-TX   F
# 6     Ahmad     V   Jabbar  987987987  1969-03-29   980-Dallas-Houston-TX   M
# 7    Alicia     J   Zelaya  999887777  1968-01-19   3321-Castle-Spring-TX   F
#
#     Salary     Superssn  Dno           Dname     Mgrssn Mgrstartdate
# 0  30000.0  333445555.0    5        Research  333445555   1988-05-22
# 1  40000.0  888665555.0    5        Research  333445555   1988-05-22
# 2  25000.0  333445555.0    5        Research  333445555   1988-05-22
# 3  38000.0  333445555.0    5        Research  333445555   1988-05-22
# 4  55000.0          NaN    1    Headquarters  888665555   1981-06-19
# 5  43000.0  888665555.0    4  Administration  987654321   1995-01-01
# 6  25000.0  987654321.0    4  Administration  987654321   1995-01-01
# 7  25000.0  987654321.0    4  Administration  987654321   1995-01-01

# %%
natural_join2(D, E, "Dnumber", "Dno")
# Out:
#             Dname  Dnumber     Mgrssn Mgrstartdate     Fname Minit    Lname  \
# 0    Headquarters        1  888665555   1981-06-19     James     E     Borg
# 1  Administration        4  987654321   1995-01-01  Jennifer     S  Wallace
# 2  Administration        4  987654321   1995-01-01     Ahmad     V   Jabbar
# 3  Administration        4  987654321   1995-01-01    Alicia     J   Zelaya
# 4        Research        5  333445555   1988-05-22      John     B    Smith
# 5        Research        5  333445555   1988-05-22  Franklin     T     Wong
# 6        Research        5  333445555   1988-05-22     Joyce     A  English
# 7        Research        5  333445555   1988-05-22    Ramesh     K  Narayan
#
#          Ssn       Bdate                 Address Sex   Salary     Superssn
# 0  888665555  1937-11-10    450-Stone-Houston-TX   M  55000.0          NaN
# 1  987654321  1941-06-20   291-Berry-Bellaire-TX   F  43000.0  888665555.0
# 2  987987987  1969-03-29   980-Dallas-Houston-TX   M  25000.0  987654321.0
# 3  999887777  1968-01-19   3321-Castle-Spring-TX   F  25000.0  987654321.0
# 4  123456789  1965-01-09  731-Fondren-Houston-TX   M  30000.0  333445555.0
# 5  333445555  1955-12-08     638-Voss-Houston-TX   M  40000.0  888665555.0
# 6  453453453  1972-07-31    5631-Rice-Houston-TX   F  25000.0  333445555.0
# 7  666884444  1962-09-15  975-Fire-Oak-Humble-TX   M  38000.0  333445555.0

# %%
natural_join2(E, D, "Ssn", "Mgrssn")
# Out:
#       Fname Minit    Lname        Ssn       Bdate                Address Sex  \
# 0  Franklin     T     Wong  333445555  1955-12-08    638-Voss-Houston-TX   M
# 1     James     E     Borg  888665555  1937-11-10   450-Stone-Houston-TX   M
# 2  Jennifer     S  Wallace  987654321  1941-06-20  291-Berry-Bellaire-TX   F
#
#     Salary     Superssn  Dno           Dname  Dnumber Mgrstartdate
# 0  40000.0  888665555.0    5        Research        5   1988-05-22
# 1  55000.0          NaN    1    Headquarters        1   1981-06-19
# 2  43000.0  888665555.0    4  Administration        4   1995-01-01

# %%
natural_join2(E, D, ["Dno", "Ssn"], ["Dnumber", "Mgrssn"])
# Out:
#       Fname Minit    Lname        Ssn       Bdate                Address Sex  \
# 0  Franklin     T     Wong  333445555  1955-12-08    638-Voss-Houston-TX   M
# 1     James     E     Borg  888665555  1937-11-10   450-Stone-Houston-TX   M
# 2  Jennifer     S  Wallace  987654321  1941-06-20  291-Berry-Bellaire-TX   F
#
#     Salary     Superssn  Dno           Dname Mgrstartdate
# 0  40000.0  888665555.0    5        Research   1988-05-22
# 1  55000.0          NaN    1    Headquarters   1981-06-19
# 2  43000.0  888665555.0    4  Administration   1995-01-01

# %%
natural_join2(E, D, ["Ssn", "Dno"], ["Mgrssn", "Dnumber"])
# Out:
#       Fname Minit    Lname        Ssn       Bdate                Address Sex  \
# 0  Franklin     T     Wong  333445555  1955-12-08    638-Voss-Houston-TX   M
# 1     James     E     Borg  888665555  1937-11-10   450-Stone-Houston-TX   M
# 2  Jennifer     S  Wallace  987654321  1941-06-20  291-Berry-Bellaire-TX   F
#
#     Salary     Superssn  Dno           Dname Mgrstartdate
# 0  40000.0  888665555.0    5        Research   1988-05-22
# 1  55000.0          NaN    1    Headquarters   1981-06-19
# 2  43000.0  888665555.0    4  Administration   1995-01-01

# %%
natural_join2(D, E, ["Dnumber", "Mgrssn"], ["Dno", "Ssn"])
# Out:
#             Dname  Dnumber     Mgrssn Mgrstartdate     Fname Minit    Lname  \
# 0    Headquarters        1  888665555   1981-06-19     James     E     Borg
# 1  Administration        4  987654321   1995-01-01  Jennifer     S  Wallace
# 2        Research        5  333445555   1988-05-22  Franklin     T     Wong
#
#         Bdate                Address Sex   Salary     Superssn
# 0  1937-11-10   450-Stone-Houston-TX   M  55000.0          NaN
# 1  1941-06-20  291-Berry-Bellaire-TX   F  43000.0  888665555.0
# 2  1955-12-08    638-Voss-Houston-TX   M  40000.0  888665555.0

# %%
natural_join2(E, E, "Superssn", "Ssn")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-dfcd0a014900> in <module>
# ----> 1 natural_join2(E, E, "Superssn", "Ssn")
#
# <ipython-input-31-12cd1585a9ee> in natural_join2(R, S, keys_R, keys_S)
#       1 def natural_join2(R, S, keys_R, keys_S):
# ----> 2     return pd.merge(R, S, left_on=keys_R, right_on=keys_S)\
#       3            .drop(keys_S, axis=1).reset_index(drop=True)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['Ssn'] not found in axis"
